# %%
import pandas as pd
import requests
import json

BEARER_TOKEN = "FILLINWITHTOKEN"

#Expects a twitter handle and potentially a token, returns a JSON-like object with all the tweets from that handle
#over the last week
def search_twitter(handle, bearer_token = BEARER_TOKEN):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    query = "from:" + handle
    tweet_fields = "tweet.fields=text,created_at"
    max_results = "max_results=100"
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}".format(
        query, tweet_fields, max_results
    )
    
    response = requests.request("GET", url, headers=headers)
    
    print(response.status_code)
    
    if response.status_code != 200:
        raise Exception(response.status_code)
    return response.json()

# %%
#Reading in the data for Congresspeople
congdf = pd.read_csv("CongressData.csv")
congdf.head()
# Out:
#             Congressperson State Party Affiliation House or Senate  District  \
# 0               Jerry Carl    AL                 R           House         1
# 1              Barry Moore    AL                 R           House         2
# 2              Mike Rogers    AL                 R           House         3
# 3          Robert Aderholt    AL                 R           House         4
# 4                Mo Brooks    AL                 R           House         5
# 5              Gary Palmer    AL                 R           House         6
# 6             Terri Sewell    AL                 D           House         7
# 7                Don Young    AK                 R           House  At-Large
# 8           Tom O'Halleran    AZ                 D           House         1
# 9          Ann Kirkpatrick    AZ                 D           House         2
# 10           Raul Grijaiva    AZ                 D           House         3
# 11              Paul Gosar    AZ                 R           House         4
# 12              Andy Biggs    AZ                 R           House         5
# 13        David Schweikert    AZ                 R           House         6
# 14           Ruben Gallego    AZ                 D           House         7
# 15            Debbie Lesko    AZ                 R           House         8
# 16            Greg Stanton    AZ                 D           House         9
# 17           Rick Crawford    AR                 R           House         1
# 18             French Hill    AR                 R           House         2
# 19            Steve Womack    AR                 R           House         3
# 20         Bruce Westerman    AR                 R           House         4
# 21            Doug LaMalfa    CA                 R           House         1
# 22           Jared Huffman    CA                 D           House         2
# 23          John Garamendi    CA                 D           House         3
# 24          Tom McClintock    CA                 R           House         4
# 25           Mike Thompson    CA                 D           House         5
# 26            Doris Matsui    CA                 D           House         6
# 27                Ami Bera    CA                 D           House         7
# 28           Jay Obernoite    CA                 R           House         8
# 29          Jerry McNerney    CA                 D           House         9
# ..                     ...   ...               ...             ...       ...
# 500             Jim Inhofe    OK                 R          Senate    Senate
# 501         James Lankford    OK                 R          Senate    Senate
# 502              Ron Wyden    OR                 D          Senate    Senate
# 503           Jeff Merkley    OR                 D          Senate    Senate
# 504          Bob Casey Jr.    PA                 D          Senate    Senate
# 505             Pat Toomey    PA                 R          Senate    Senate
# 506              Jack Reed    RI                 D          Senate    Senate
# 507     Sheldon Whitehouse    RI                 D          Senate    Senate
# 508         Lindsey Graham    SC                 R          Senate    Senate
# 509              Tim Scott    SC                 R          Senate    Senate
# 510             John Thune    SD                 R          Senate    Senate
# 511            Mike Rounds    SD                 R          Senate    Senate
# 512       Marsha Blackburn    TN                 R          Senate    Senate
# 513           Bill Hagerty    TN                 R          Senate    Senate
# 514            John Cornyn    TX                 R          Senate    Senate
# 515               Ted Cruz    TX                 R          Senate    Senate
# 516               Mike Lee    UT                 R          Senate    Senate
# 517            Mitt Romney    UT                 R          Senate    Senate
# 518          Patrick Leahy    VT                 D          Senate    Senate
# 519         Bernie Sanders    VT                 I          Senate    Senate
# 520            Mark Warner    VA                 D          Senate    Senate
# 521              Tim Kaine    VA                 D          Senate    Senate
# 522           Patty Murray    WA                 D          Senate    Senate
# 523         Maria Cantwell    WA                 D          Senate    Senate
# 524            Joe Manchin    WV                 D          Senate    Senate
# 525  Shelley Moore. Capito    WV                 R          Senate    Senate
# 526            Ron Johnson    WI                 R          Senate    Senate
# 527          Tammy Baldwin    WI                 R          Senate    Senate
# 528          John Barrasso    WY                 R          Senate    Senate
# 529         Cynthia Lummis    WY                 R          Senate    Senate
#
#          Race Gender Birthdate                              Background  \
# 0       White      M   6/17/58                               Political
# 1       White      M   9/26/66                               Political
# 2       White      M   7/16/58                               Political
# 3       White      M   7/22/65                                   Legal
# 4       White      M   4/29/54                               Political
# 5       White      M   5/14/54                               Political
# 6       Black      F    1/1/65                                   Legal
# 7       White      M    6/9/33                               Political
# 8       White      M   1/24/46                               Political
# 9       White      F   3/24/50                               Political
# 10   Hispanic      M   2/19/48                               Political
# 11      White      M  11/27/58                                 Medical
# 12      White      M   11/7/58                               Political
# 13      White      M    3/3/62                               Political
# 14   Hispanic      M  11/20/79                               Political
# 15      White      F  11/14/58                               Political
# 16      White      M    3/8/70                               Political
# 17      White      M   1/22/66                         Media, Business
# 18      White      M   12/5/56                                Business
# 19      White      M   2/18/57                               Political
# 20      White      M  11/18/67                               Political
# 21      White      M    7/2/60                               Political
# 22      White      M   2/18/64                               Political
# 23   Hispanic      M   1/24/45                               Political
# 24      White      M   7/10/56                               Political
# 25      White      M   1/24/51                               Political
# 26      Asian      F   9/25/44                               Political
# 27      Asian      M    3/2/65                                 Medical
# 28      White      M   8/18/70                               Political
# 29      White      M   6/18/51                             Engineering
# ..        ...    ...       ...                                     ...
# 500     White      M  11/17/34         Military,  Businness, Political
# 501     White      M    3/4/68                    Education, Political
# 502     White      M    5/3/49                    Education, Political
# 503     White      M  10/24/56                 Intelligence, Political
# 504     White      M   4/13/60             Education, Legal, Political
# 505     White      M  11/17/61                     Business, Political
# 506     White      M  11/12/49              Military, Legal, Political
# 507     White      M  10/20/55                        Legal, Political
# 508     White      M    7/9/55              Legal, Military, Political
# 509     Black      M   9/19/65                     Business, Political
# 510     White      M    1/7/61                               Political
# 511     White      M  10/24/54                     Business, Political
# 512     White      F    6/6/52                    Business,  Political
# 513     White      M   8/14/59                     Business, Political
# 514     White      M    2/2/52                        Legal, Political
# 515  Hispanic      M  12/22/70                                   Legal
# 516     White      M    6/4/71                                   Legal
# 517     White      M   3/12/47                     Business, Political
# 518     White      M   3/31/00                        Legal, Political
# 519     White      M    9/8/41                        Media, Political
# 520     White      M  12/15/54                     Business, Political
# 521     White      M   2/26/58  Political, Legal, Education, Religious
# 522     White      F  10/11/50                    Education, Political
# 523     White      F  10/13/58                     Business, Political
# 524     White      M   8/24/47                     Business, Political
# 525     White      F  11/26/53          Academic, Education, Political
# 526     White      M    4/9/55                                Business
# 527     White      F   2/11/62                        Legal, Political
# 528     White      M   7/21/52                      Medical, Political
# 529     White      F   9/10/54                        Legal, Political
#
#       Twitter Handle
# 0       RepJerryCarl
# 1      RepBarryMoore
# 2    RepMikeRogersAL
# 3    Robert_Aderholt
# 4        RepMoBrooks
# 5    USRepGaryPalmer
# 6     RepTerriSewell
# 7        RepDonYoung
# 8       repohalleran
# 9     RepKirkpatrick
# 10   RepraulGrijalva
# 11          RepGosar
# 12    RepAndyBiggsAZ
# 13          RepDavid
# 14   RepRubenGallego
# 15         RepDLesko
# 16    RepGregStanton
# 17   RepRickCrawford
# 18     RepFrenchHill
# 19   rep_stevewomack
# 20      RepWesterman
# 21        RepLaMalfa
# 22        RepHuffman
# 23      RepGaramendi
# 24     RepMcCLintock
# 25       RepThompson
# 26       DorisMatsui
# 27           RepBera
# 28      JayObernolte
# 29       RepMcNerney
# ..               ...
# 500        JimInhofe
# 501  SenatorLankford
# 502         RonWyden
# 503   SenJeffMerkley
# 504      SenBobCasey
# 505        SenToomey
# 506      senjackreed
# 507    SenWhitehouse
# 508  LindseyGrahamSC
# 509  SenatorTimScott
# 510     SenJohnThune
# 511    SenatorRounds
# 512  MarshaBlackburn
# 513   SenatorHagerty
# 514       JohnCornyn
# 515       SenTedCruz
# 516       SenMikeLee
# 517    SenatorRomney
# 518     SenatorLeahy
# 519       SenSanders
# 520       MarkWarner
# 521         timkaine
# 522      PattyMurray
# 523  SenatorCantwell
# 524   Sen_JoeManchin
# 525        SenCapito
# 526    SenRonJohnson
# 527   SenatorBaldwin
# 528  SenJohnBarrasso
# 529        SenLummis
#
# [530 rows x 10 columns]

# %%
#Creating empty DataFrame with the columns we will need for each tweet

tweetsdf = pd.DataFrame({
    'Name':[],
    'Twitter Handle':[],
    'Time':[],
    'Content': []
})
tweetsdf
# Out:
# Empty DataFrame
# Columns: [Name, Twitter Handle, Time, Content]
# Index: []

# %%
#Query limit per 15 minutes is 300, so this will start returning 429 (Too many requests) errors if you're using a free developer account for the API
#Just change the starting point to wherever it fails and then resume after waiting 15 minutes
for i in range(len(congdf['Congressperson'])):
    if congdf['Twitter Handle'][i] != "None?":
        try:
            json_response = search_twitter(congdf["Twitter Handle"][i])
            for tweet in json_response["data"]:
                tweetsdf.loc[len(tweetsdf['Name'])] = [congdf['Congressperson'][i]] + [congdf['Twitter Handle'][i]] + [tweet['created_at']] + [tweet['text']]
        except Exception as exc:
            print(exc)
            if(exc == 429):
                print(i)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 'data'
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 'data'
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 'data'
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
tweetsdf.head()
# Out:
#                  Name   Twitter Handle                      Time  \
# 0          Jerry Carl     RepJerryCarl  2021-06-18T18:38:29.000Z
# 1          Jerry Carl     RepJerryCarl  2021-06-18T15:45:03.000Z
# 2          Jerry Carl     RepJerryCarl  2021-06-17T23:39:56.000Z
# 3          Jerry Carl     RepJerryCarl  2021-06-17T21:38:03.000Z
# 4          Jerry Carl     RepJerryCarl  2021-06-17T21:37:45.000Z
# 5          Jerry Carl     RepJerryCarl  2021-06-17T20:28:36.000Z
# 6          Jerry Carl     RepJerryCarl  2021-06-17T20:19:25.000Z
# 7          Jerry Carl     RepJerryCarl  2021-06-17T18:58:11.000Z
# 8          Jerry Carl     RepJerryCarl  2021-06-17T18:51:57.000Z
# 9          Jerry Carl     RepJerryCarl  2021-06-17T16:11:32.000Z
# 10         Jerry Carl     RepJerryCarl  2021-06-16T13:50:28.000Z
# 11         Jerry Carl     RepJerryCarl  2021-06-15T15:13:07.000Z
# 12         Jerry Carl     RepJerryCarl  2021-06-15T14:43:51.000Z
# 13         Jerry Carl     RepJerryCarl  2021-06-14T20:28:33.000Z
# 14         Jerry Carl     RepJerryCarl  2021-06-14T18:44:23.000Z
# 15         Jerry Carl     RepJerryCarl  2021-06-14T14:38:28.000Z
# 16        Barry Moore    RepBarryMoore  2021-06-18T17:30:09.000Z
# 17        Barry Moore    RepBarryMoore  2021-06-18T17:30:00.000Z
# 2              @Truth_Gazette @CarlForAlabama Thank you!
# 3                  @JonathanAHester Thank you, Jonathan!
# 4                                @gopclassics Thank you!
# 5      @ChairmanLathan @ALGOP Thank you! I appreciate...
# 6      Thank you, Barry! Proud to serve with you. htt...
# 7      Thank you, Kat! It’s an honor to serve with yo...
# 8                               @NatResources Thank you!
# 9                 @RepBlakeMoore Congratulations, Blake!
# 10     Taxpayer money should NEVER be used to perform...
# 11     RT @RepMoBrooks: .@RepJerryCarl &amp; I were j...
# 12     The ATF is proposing guidance to strip #2A rig...
# 13     RT @yhn: .@RepMoBrooks, @RepJerryCarl request ...
# 14     RT @RepHarshbarger: I joined @RepJerryCarl in ...
# 15             #FlagDay 🇺🇸 🇺🇸 🇺🇸 https://t.co/WmR4yEqGdB
# 16     RT @GovernorKayIvey: Folks, pay close attentio...
# 17     Human smugglers continue to take advantage of ...
# 18     Sickening.\n\nFor the record, @SpeakerPelosi, ...
# 19     RT @HouseGOP: Does she even know where it is? ...
# 20     Happy birthday to my friend and colleague, @Re...
# 21     This exchange is incredibly disturbing. I'll b...
# 22     RT @RepLisaMcClain: Thank you to the Supreme C...
# 23     We've gone from America First to Americans Las...
# 24     RT @HouseAgGOP: The For the 99.5% Act would im...
# 25     During the Geneva summit, Biden gave Putin a c...
# 26             🚨 Tune in, #AL02! https://t.co/VYam3RssWj
# 27     Biden ➡️ The border is "under control"\nHarris...
# 28     RT @SteveScalise: Unbelievable. Andrew McCabe ...
# 29     RT @HouseGOP: CBP has already seized MORE fent...
# ...                                                  ...
# 11892  RT @ChuckGrassley: If Biden admin decides 2go ...
# 11893  RT @SpeakerPelosi: Join my colleagues and me l...
# 11894  RT @MarshaBlackburn: Biden’s solution? Push pr...
# 11895  RT @SenateGOP: MUST READ\n \nThe surge in ille...
# 11896  Today we celebrate our nation’s flag. A symbol...
# 11897  This year’s @WyoBoysState delegates are gearin...
# 11898  Congratulations to Mills as they celebrate bec...
# 11899  Thank you to the Wyoming Shriners for hosting ...
# 11900  The 2021 WY @Girls_State delegates have a prom...
# 11901  A special thank you to the Greater Cheyenne Ch...
# 11902  It’s #NationalGoFishingDay! Fly fishing is one...
# 11903  When I’m home in Wyoming, the number one conce...
# 11904  You don’t have to be a former state treasurer ...
# 11905  .@GovernorGordon put his foot down and told fe...
# 11906  “Lummis forcefully made the case that bitcoin ...
# 11907  RT @SenRickScott: The U.S. debt is nearly $30T...
# 11908  After assurances that the EPA would work with ...
# 11909  Thanks @Varneyco and @hillary__vaughn for reco...
# 11910    It’s still a crisis.\n\nhttps://t.co/w1FL9vKlhl
# 11911  Congress should not sit idly by as this lawsui...
# 11912  Congress created numerous laws requiring miner...
# 11913  Judge Terry Doughty sees the Biden ban on oil ...
# 11914  RT @SenatorBraun: President Biden claims he wo...
# 11915  A third of Americans aren’t interested in spen...
# 11916  RT @SenatorSinema: Happy #FlagDay, Arizona! ht...
# 11917  RT @SenJoniErnst: As we celebrate #FlagDay, le...
# 11918  That’s why we introduced the Pay Down the Debt...
# 11919  .@SenRickScott turned down billions for a ligh...
# 11920  RT @SenBillCassidy: There still is a crisis at...
# 11921  Today we celebrate all the women who have serv...
#
# [11922 rows x 4 columns]

# %%
from datetime import date

tweetsdf.to_csv("Tweets" + str(today.strftime("%m%d%Y")) + ".csv")
# Out:
# 06192021
